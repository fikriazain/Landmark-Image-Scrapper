# %%
import pandas as pd

# %%
df = pd.read_excel('city_image_download_summary.xlsx')

# %%
x = df['CITY'].unique()
for city in x:
    print(f"Processing {city}...")
# Out:
# Processing Banyuasin...
# Processing Dogiyai...
# Processing Dumai...
# Processing Paniai...
# Processing Cilegon...
# Processing Malaka...
# Processing Sumba...
# Processing Seruyan...
# Processing Toli Toli...
# Processing Buton Tengah...
# Processing Melawi...
# Processing Jayapura...
# Processing Timor Tengah Utara...
# Processing Musi Rawas Utara...
# Processing Buton Utara...
# Processing Sijunjung...
# Processing Lanny Jaya...
# Processing Bau-Bau...
# Processing Cikarang...
# Processing Bolaang Mongondow...
# Processing Tongging...
# Processing Singkawang...
# Processing Wonosobo...
# Processing Bengkayang Regency...
# Processing Pamekasan...
# Processing Pinrang...
# Processing Murung Raya...
# Processing Majalengka...
# Processing Serdang Bedagai...
# Processing Cirebon...
# Processing Lubuk Linggau...
# Processing Dharmasraya...
# Processing Supiori...
# Processing Kab Timor Tengah Selatan...
# Processing Balikpapan...
# Processing Ngada...
# Processing Batu Bara...
# ...
